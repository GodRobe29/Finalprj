# %% [markdown]
# <a href="https://colab.research.google.com/github/GodRobe29/Finalprj/blob/main/Chapter_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PREDICTING THE EFFECT OF THE NIGERIAN STOCK EXCHANGE PERFORMANCE ON INDUSTRIAL PRODUCTIVITY VIA MACHINE LEARNING**

# %% [markdown]
# # **Chapter 4 ML Data Analysis and presentation**

# %% [markdown]
# # **Data Preprocessing**

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/GodRobe29/Finalprj/main/Data%20Chapter%204%20Prjctttt%20-%20Sheet1.csv')
df
# Out:
#     Market Capitalization ₦ Billion  All share Index  \
# 0                             31.20          1107.60
# 1                             47.50          1543.80
# 2                             66.30          2205.00
# 3                            180.40          5092.20
# 4                            285.80          6992.10
# 5                            281.90          6440.50
# 6                            262.60          5672.70
# 7                            300.00          5266.40
# 8                            472.30          8111.00
# 9                            662.50         10963.10
# 10                           764.90         12137.70
# 11                          1359.30         20128.94
# 12                          2112.50         23844.50
# 13                          2900.06         24085.80
# 14                          5120.90         33189.30
# 15                         13181.69         57990.20
# 16                          9562.97         31450.78
# ...

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Data Separation into Dependent and Independent variables (Y & X)**

# %% [markdown]
# **Dependent Variable Y**

# %%
y = df['Industrial Productivity ₦ Billion']
y
# Out:
# 0       341.66
# 1       417.06
# 2       553.96
# 3      1132.84
# 4      1530.05
# 5      1557.54
# 6      1379.20
# 7      1609.82
# 8      2388.83
# 9      2328.41
# 10     2650.03
# 11     3525.14
# 12     5145.43
# 13     6520.74
# 14     7822.11
# 15     8441.76
# 16     9874.38
# 17     9229.81
# 18    13826.43
# 19    17853.11
# 20    19587.72
# 21    20853.85
# 22    22213.01
# 23    19188.58
# 24    18641.17
# 25    25639.90
# 26    33218.33
# 27    39879.69
# 28    43530.78
# 29    55300.97
# Name: Industrial Productivity ₦ Billion, dtype: float64

# %% [markdown]
# ## **Independent X Variables**

# %%
X = df.drop('Industrial Productivity ₦ Billion', axis=1 )
X
# Out:
#     Market Capitalization ₦ Billion  All share Index  \
# 0                             31.20          1107.60
# 1                             47.50          1543.80
# 2                             66.30          2205.00
# 3                            180.40          5092.20
# 4                            285.80          6992.10
# 5                            281.90          6440.50
# 6                            262.60          5672.70
# 7                            300.00          5266.40
# 8                            472.30          8111.00
# 9                            662.50         10963.10
# 10                           764.90         12137.70
# 11                          1359.30         20128.94
# 12                          2112.50         23844.50
# 13                          2900.06         24085.80
# 14                          5120.90         33189.30
# 15                         13181.69         57990.20
# 16                          9562.97         31450.78
# ...

# %% [markdown]
# ## **Data Splitting**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split (X, y, test_size =0.2, random_state =100)

# %%
X_train
# Out:
#     Market Capitalization ₦ Billion  All share Index  \
# 27                         25890.22         26842.07
# 25                         21128.90         38243.19
# 6                            262.60          5672.70
# 17                          7030.84         20827.17
# 22                         16875.10         34657.15
# 11                          1359.30         20128.94
# 4                            285.80          6992.10
# 29                         42054.50         42716.44
# 0                             31.20          1107.60
# 1                             47.50          1543.80
# 18                          9918.21         24770.52
# 14                          5120.90         33189.30
# 19                         10275.34         20730.63
# 21                         19077.42         41329.19
# 2                             66.30          2205.00
# 20                         14800.94         28078.81
# 10                           764.90         12137.70
# ...

# %%
X_test
# Out:
#     Market Capitalization ₦ Billion  All share Index  \
# 9                            662.50         10963.10
# 26                         21904.04         31430.50
# 28                         38589.58         40270.72
# 13                          2900.06         24085.80
# 5                            281.90          6440.50
# 12                          2112.50         23844.50
#
#     Value of Shares Traded ₦ Billion  Number Of Deals  Interest Rate  \
# 9                              57.68         426163.0           0.12
# 26                           1203.37        1048777.0           0.06
# 28                           1086.18        1156830.0           0.05
# 13                            262.94        1021966.6          -0.02
# 5                              10.33          78089.0           0.12
# 12                            225.82         973526.0          -0.03
#
#     Inflation Rate  Money Supply M3 ₦ Billion
# 9             0.19                    1309.36
# ...

# %%
y_test
# Out:
# 9      2328.41
# 26    33218.33
# 28    43530.78
# 13     6520.74
# 5      1557.54
# 12     5145.43
# Name: Industrial Productivity ₦ Billion, dtype: float64

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## **Linear Regression**

# %% [markdown]
# **Training the model**

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression ()
lr.fit(X_train, y_train,)
# Out:
# LinearRegression()

# %% [markdown]
# **Applying the model to make prediction**

# %%
y_lr_train_pred = lr.predict(X_train)
y_lr_test_pred = lr.predict(X_test)

# %%
y_lr_train_pred
# Out:
# array([36460.02535105, 25390.90358906,  2019.99776405,  9283.35501354,
#        20907.9323475 ,   819.48872493,  1428.6658234 , 56118.33159495,
#         2817.56226486,   -80.28602239, 13791.62712377,  5414.76157824,
#        14781.56902979, 20844.68010561,   634.60882078, 19094.28616259,
#         2381.73447011, 10999.50902751, 10311.56257134, 21155.79097469,
#         2981.15706266,    87.24930523, 22773.25605207,  3463.31126465])

# %%
y_lr_test_pred
# Out:
# array([ 1056.18518349, 29023.28536385, 50906.13938238,  3097.86492771,
#         1858.58206476,  2418.77693026])

# %% [markdown]
# ## **Evaluate model performance**

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %% [markdown]
# ## **Print Results**

# %%
print('LR MSE (Train): ', lr_train_mse)
print('LR R2 (Train): ', lr_train_r2)
print('LR MSE (Test): ', lr_test_mse)
print('LR R2 (Test): ', lr_test_r2)
# Out:
# LR MSE (Train):  3068191.2674609
# LR R2 (Train):  0.9830522871088774
# LR MSE (Test):  15475703.091719223
# LR R2 (Test):  0.9439052279692867

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method    Training MSE Training R2         Test MSE   Test R2
# 0  Linear regression  3068191.267461    0.983052  15475703.091719  0.943905

# %% [markdown]
# # **Random Forest Model**

# %% [markdown]
# ## **Training the Model**

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# **Applying the model to make prediction**

# %%
y_rf_train_pred = rf.predict(X_train)
y_rf_test_pred = rf.predict(X_test)

# %% [markdown]
# ## **Evaluate model performance**

# %%
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method     Training MSE Training R2        Test MSE  Test R2
# 0  Random forest  10520113.747336     0.94189  8891892.401149  0.96777

# %% [markdown]
# ## **Model comparism**

# %%
df_models = pd.concat([lr_results, rf_results], axis=0)

# %%
df_models.reset_index(drop=True)
# Out:
#               Method     Training MSE Training R2         Test MSE   Test R2
# 0  Linear regression   3068191.267461    0.983052  15475703.091719  0.943905
# 1      Random forest  10520113.747336     0.94189   8891892.401149   0.96777

# %% [markdown]
# ## **Data Visualisation**

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.scatter(x=y_train, y=y_lr_train_pred, c="#7CAE00" ,alpha=0.3)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict LogS')
plt.xlabel('Experimental LogS')
# Out:
# Text(0.5, 0, 'Experimental LogS')
